# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
with np.load("flows.npz", encoding="latin1") as data:
    xA = data['xA']
    xB = data['xB']
    xC = data['xC']
    t  = data['t']

# %%
xA.shape
# Out:
# (51, 5000, 2)

# %%
fig, ax = plt.subplots()
ax.scatter(xA[0,:,0], xA[0,:,1])
